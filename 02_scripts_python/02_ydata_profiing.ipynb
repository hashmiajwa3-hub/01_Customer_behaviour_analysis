# %% [markdown]
# # EDA for Customer Data

# %%
import ydata_profiling as yd
import pandas as pd

# %%
df = pd.read_csv('customer_shopping_behavior.csv')
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0        Express              Yes             Yes                  14
# 1        Express              Yes             Yes                   2
# 2  Free Shipping              Yes             Yes                  23
# 3   Next Day Air              Yes             Yes                  49
# 4  Free Shipping              Yes             Yes                  31
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually

# %%
# ydata profile report
profile = yd.ProfileReport(df)
profile.to_file(output_file="./03_ydata_customer.html")
# Out:
# 100%|██████████| 18/18 [00:00<00:00, 23.98it/s]0<00:00, 24.42it/s, Describe variable: Frequency of Purchases]
# Summarize dataset: 100%|██████████| 52/52 [00:08<00:00,  6.28it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:06<00:00,  6.40s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.55it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 54.99it/s]

# %% [markdown]
# # Data Skimming

# %%
import skimpy as sk

# %%
from skimpy import skim

# %%
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 3900   │ │ string      │ 13    │                                                          │
# │ │ Number of columns │ 18     │ │ int64       │ 4     │                                                          │
# │ └───────────────────┴────────┘ │ float64     │ 1     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━┳━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━┳━━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━┳━━━━━━━━┓  │
# │ ┃ column               ┃ NA ┃ NA %               ┃ mean  ┃ sd    ┃ p0  ┃ p25   ┃ p50  ┃ p75  ┃ p100 ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━╇━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━╇━━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━╇━━━━━━━━┩  │
# │ │ Customer ID          │  0 │                  0 │  1950 │  1126 │   1 │ 975.8 │ 1950 │ 2925 │ 3900 │ ▇▇▇▇▇▇ │  │
# │ │ Age                  │  0 │                  0 │ 44.07 │ 15.21 │  18 │    31 │   44 │   57 │   70 │ ▇▇▇▇▇▇ │  │
# │ │ Purchase Amount      │  0 │                  0 │ 59.76 │ 23.69 │  20 │    39 │   60 │   81 │  100 │ ▇▇▇▇▇▇ │  │
# │ │ (USD)                │    │                    │       │       │     │       │      │      │      │        │  │
# │ │ Review Rating        │ 37 │ 0.9487179487179487 │  3.75 │ 0.717 │ 2.5 │   3.1 │  3.8 │  4.4 │    5 │ ▇▇▇▇▇▇ │  │
# │ │ Previous Purchases   │  0 │                  0 │ 25.35 │ 14.45 │   1 │    13 │   25 │   38 │   50 │ ▇▇▇▇▇▇ │  │
# │ └──────────────────────┴────┴────────────────────┴───────┴───────┴─────┴───────┴──────┴──────┴──────┴────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┓  │
# │ ┃           ┃    ┃      ┃          ┃           ┃           ┃           ┃ chars per  ┃ words per ┃ total      ┃  │
# │ ┃ column    ┃ NA ┃ NA % ┃ shortest ┃ longest   ┃ min       ┃ max       ┃ row        ┃ row       ┃ words      ┃  │
# │ ┡━━━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━┩  │
# │ │ Gender    │  0 │    0 │ Male     │ Female    │ Female    │ Male      │       4.64 │         1 │       3900 │  │
# │ │ Item      │  0 │    0 │ Hat      │ Sunglasse │ Backpack  │ T-shirt   │       5.87 │         1 │       3900 │  │
# │ │ Purchased │    │      │          │ s         │           │           │            │           │            │  │
# │ │ Category  │  0 │    0 │ Clothing │ Accessori │ Accessori │ Outerwear │       9.04 │         1 │       3900 │  │
# │ │           │    │      │          │ es        │ es        │           │            │           │            │  │
# │ │ Location  │  0 │    0 │ Ohio     │ North     │ Alabama   │ Wyoming   │       8.43 │       1.2 │       4657 │  │
# │ │           │    │      │          │ Carolina  │           │           │            │           │            │  │
# │ │ Size      │  0 │    0 │ L        │ XL        │ L         │ XL        │       1.11 │         1 │       3900 │  │
# │ │ Color     │  0 │    0 │ Red      │ Turquoise │ Beige     │ Yellow    │       5.43 │         1 │       3900 │  │
# │ │ Season    │  0 │    0 │ Fall     │ Winter    │ Fall      │ Winter    │        5.5 │         1 │       3900 │  │
# │ │ Subscript │  0 │    0 │ No       │ Yes       │ No        │ Yes       │       2.27 │         1 │       3900 │  │
# │ │ ion       │    │      │          │           │           │           │            │           │            │  │
# │ │ Status    │    │      │          │           │           │           │            │           │            │  │
# │ │ Shipping  │  0 │    0 │ Express  │ 2-Day     │ 2-Day     │ Store     │         11 │       1.8 │       7148 │  │
# │ │ Type      │    │      │          │ Shipping  │ Shipping  │ Pickup    │            │           │            │  │
# │ │ Discount  │  0 │    0 │ No       │ Yes       │ No        │ Yes       │       2.43 │         1 │       3900 │  │
# │ │ Applied   │    │      │          │           │           │           │            │           │            │  │
# │ │ Promo     │  0 │    0 │ No       │ Yes       │ No        │ Yes       │       2.43 │         1 │       3900 │  │
# │ │ Code Used │    │      │          │           │           │           │            │           │            │  │
# │ │ Payment   │  0 │    0 │ Cash     │ Bank      │ Bank      │ Venmo     │        8.1 │       1.5 │       5819 │  │
# │ │ Method    │    │      │          │ Transfer  │ Transfer  │           │            │           │            │  │
# │ │ Frequency │  0 │    0 │ Weekly   │ Every 3   │ Annually  │ Weekly    │       9.18 │       1.3 │       5068 │  │
# │ │ of        │    │      │          │ Months    │           │           │            │           │            │  │
# │ │ Purchases │    │      │          │           │           │           │            │           │            │  │
# │ └───────────┴────┴──────┴──────────┴───────────┴───────────┴───────────┴────────────┴───────────┴────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯
